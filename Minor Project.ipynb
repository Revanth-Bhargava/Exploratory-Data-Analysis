# %% [markdown]
# # REVANTH BHARGAVA BOYIDI
# MLB1-MINOR-APRIL

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # READING THE DATASET

# %%
df=pd.read_csv('StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# # NULL VALUES

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# AS THERE ARE 3 MARKS, THERE AVERAGE IS TAKEN FOR FOR BETTER UNDERSTANDING

# %%
df['Avg score']=(df['math score'] + df['reading score'] + df['writing score'])/3
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  Avg score
# 0                    none          72             72             74  72.666667
# 1               completed          69             90             88  82.333333
# 2                    none          90             95             93  92.666667
# 3                    none          47             57             44  49.333333
# 4                    none          76             78             75  76.333333

# %%
df.gender.value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
plt.subplot(1,2,1)
df.gender.value_counts().plot(kind='bar')
plt.subplot(1,2,2)
df.gender.value_counts().plot(kind='pie')

# %%
df.rename(columns={'race/ethnicity':'race'},inplace=True)
df.race.value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race, dtype: int64

# %%
plt.subplot(1,2,1)
df.race.value_counts().plot(kind='bar')
plt.subplot(1,2,2)
df.race.value_counts().plot(kind='pie')

# %%
df.rename(columns={'parental level of education':'parental_level_of_education'},inplace=True)
df.parental_level_of_education.value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental_level_of_education, dtype: int64

# %%
df.parental_level_of_education.value_counts().plot(kind='bar')

# %%
df.lunch.value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
plt.subplot(1,2,1)
df.lunch.value_counts().plot(kind='bar')
plt.subplot(1,2,2)
df.lunch.value_counts().plot(kind='pie')

# %%
df.rename(columns={'test preparation course':'test_preparation_course'},inplace=True)
df.test_preparation_course.value_counts()
# Out:
# none         642
# completed    358
# Name: test_preparation_course, dtype: int64

# %%
plt.subplot(1,2,1)
df.test_preparation_course.value_counts().plot(kind='bar')
plt.subplot(1,2,2)
df.test_preparation_course.value_counts().plot(kind='pie')

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(df['math score'],kde=True,color='b',bins=list(range(0,105,5)))
plt.subplot(1,2,2)
sns.violinplot(y='math score',data=df)

# %% [markdown]
# MOST OF THE STUDENTS HAVE SCORED IN THE RANGE 60 - 80 IN MATHS

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(df['reading score'],kde=True,color='b',bins=list(range(0,105,5)))
plt.subplot(1,2,2)
sns.violinplot(y='reading score',data=df)

# %% [markdown]
# MOST OF THE STUDENTS HAVE SCORED IN THE RANGE 70 - 85 IN READING

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(df['writing score'],kde=True,color='b',bins=list(range(0,105,5)))
plt.subplot(1,2,2)
sns.violinplot(y='writing score',data=df)

# %% [markdown]
# MOST OF THE STUDENTS HAVE SCORED IN THE RANGE 65 - 85 IN WRITING

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.distplot(df['Avg score'],kde=True,color='b',bins=list(range(0,105,5)))
plt.subplot(1,2,2)
sns.violinplot(y='Avg score',data=df)

# %% [markdown]
# MOST OF THE STUDENTS HAVE SCORED IN THE RANGE 65 - 80 IN TOTAL

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='gender',y='math score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='gender',y='math score',data=df)

# %% [markdown]
# MALE STUDENTS HAVE PERFORMED BETTER IN MATHS

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='gender',y='reading score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='gender',y='reading score',data=df)

# %% [markdown]
# FEMALE STDENTS HAVE PERFORMED BETTER IN READING

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='gender',y='writing score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='gender',y='writing score',data=df)

# %% [markdown]
# FEMALE STDENTS HAVE PERFORMED BETTER IN WRITING

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='gender',y='Avg score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='gender',y='Avg score',data=df)

# %% [markdown]
# FEMALE STDENTS ARE PERFORMING BETTER THAN MALE STUDENTS

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='race',y='math score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='race',y='math score',data=df)

# %% [markdown]
#  STUDENTS OF GROUP E HAVE PERFORMED BETTER IN MATHS WHILE GROUP A HAVE SHOWN THE LEAST PERFORMANCE

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='race',y='reading score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='race',y='reading score',data=df)

# %% [markdown]
# STUDENTS OF GROUP E HAVE PERFORMED BETTER IN READING WHILE GROUP A HAVE SHOWN THE LEAST PERFORMANCE

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='race',y='writing score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='race',y='writing score',data=df)

# %% [markdown]
# STUDENTS OF GROUP E AND GROUP D HAVE PERFORMED BETTER IN WRITING WHILE GROUP A HAVE SHOWN THE LEAST PERFORMANCE

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='race',y='Avg score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='race',y='Avg score',data=df)

# %% [markdown]
# STUDENTS OF GROUP E HAVE PERFORMED BETTER IN OVERALL WHILE GROUP A HAVE SHOWN THE LEAST PERFORMANCE

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.barplot(y='parental_level_of_education',x='math score',data=df)
plt.subplot(1,2,2)
sns.boxplot(y='parental_level_of_education',x='math score',data=df)

# %% [markdown]
# STUDENTS WHOSE PARENTS HAVE A MASTER'S DEGREE OR BACHELOR'S DEGREE HAVE SHOWN THE BEST PERFORMANCE IN MATHS
# STUDENTS WHOSE PARENTS HAVE A GONE TILL HIGH SCHOOL HAVE SHOWN THE LEAST PERFORMANCE IN MATHS

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.barplot(y='parental_level_of_education',x='reading score',data=df)
plt.subplot(1,2,2)
sns.boxplot(y='parental_level_of_education',x='reading score',data=df)

# %% [markdown]
# STUDENTS WHOSE PARENTS HAVE A MASTER DEGREE HAVE SHOWN THE BEST PERFORMANCE IN READING
# STUDENTS WHOSE PARENTS HAVE A GONE TILL HIGH SCHOOL HAVE SHOWN THE LEAST PERFORMANCE IN READING

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.barplot(y='parental_level_of_education',x='writing score',data=df)
plt.subplot(1,2,2)
sns.boxplot(y='parental_level_of_education',x='writing score',data=df)

# %% [markdown]
# STUDENTS WHOSE PARENTS HAVE A MASTER DEGREE HAVE SHOWN THE BEST PERFORMANCE IN WRITING
# STUDENTS WHOSE PARENTS HAVE A GONE TILL HIGH SCHOOL HAVE SHOWN THE LEAST PERFORMANCE IN WRITING

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.barplot(y='parental_level_of_education',x='Avg score',data=df)
plt.subplot(1,2,2)
sns.boxplot(y='parental_level_of_education',x='Avg score',data=df)

# %% [markdown]
# STUDENTS WHOSE PARENTS HAVE A MASTER DEGREE HAVE SHOWN THE BEST PERFORMANCE IN ALL THE TESTS
# STUDENTS WHOSE PARENTS HAVE A GONE TILL HIGH SCHOOL HAVE SHOWN THE LEAST PERFORMANCE IN TESTS

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='lunch',y='math score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='lunch',y='math score',data=df)

# %% [markdown]
# STUDENTS WHO CAN AFFORD STANDARD LUNCH ARE PERFORMING BETTER IN MATHS COMPARED TO STUDENTS WHO GET FREE/REDUCED LUNCH

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='lunch',y='reading score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='lunch',y='reading score',data=df)

# %% [markdown]
# STUDENTS WHO CAN AFFORD STANDARD LUNCH ARE PERFORMING BETTER IN READING COMPARED TO STUDENTS WHO GET FREE/REDUCED LUNCH

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='lunch',y='writing score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='lunch',y='writing score',data=df)

# %% [markdown]
# STUDENTS WHO CAN AFFORD STANDARD LUNCH ARE PERFORMING BETTER IN WRITING COMPARED TO STUDENTS WHO GET FREE/REDUCED LUNCH

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='lunch',y='Avg score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='lunch',y='Avg score',data=df)

# %% [markdown]
# STUDENTS WHO CAN AFFORD STANDARD LUNCH ARE PERFORMING BETTER IN ALL TESTS COMPARED TO STUDENTS WHO GET FREE/REDUCED LUNCH

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='test_preparation_course',y='math score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='test_preparation_course',y='math score',data=df)

# %% [markdown]
# STUDENTS WHO COMPLETED THE TEST PREPARATION COURSE ARE PERFORMING BETTER IN MATHS THAN OTHER STUDENTS WHO HAVEN'T

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='test_preparation_course',y='reading score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='test_preparation_course',y='reading score',data=df)

# %% [markdown]
# STUDENTS WHO COMPLETED THE TEST PREPARATION COURSE ARE PERFORMING BETTER IN READING THAN OTHER STUDENTS WHO HAVEN'T

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='test_preparation_course',y='writing score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='test_preparation_course',y='writing score',data=df)

# %% [markdown]
# STUDENTS WHO COMPLETED THE TEST PREPARATION COURSE ARE PERFORMING BETTER IN WRITING THAN OTHER STUDENTS WHO HAVEN'T

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='test_preparation_course',y='Avg score',data=df)
plt.subplot(1,2,2)
sns.boxplot(x='test_preparation_course',y='Avg score',data=df)

# %% [markdown]
# STUDENTS WHO COMPLETED THE TEST PREPARATION COURSE ARE PERFORMING BETTER IN ALL TESTS THAN OTHER STUDENTS WHO HAVEN'T

# %% [markdown]
# ## INFERENCES:-

# %% [markdown]
# PARENTS'S EDUCATION LEVEL IS AFFECTING THE STUDENTS PERFORMANCE AS THEY THEY CAN GUIDE THEM.
#
# TEST PREPARATION COURSE IS REALLY USEFUL IN IMPROVING THE TEST PERFORMANCE.

# %%
sns.barplot(x='race',y='math score',data=df,hue='parental_level_of_education')

# %% [markdown]
# IN GROUP A, STUDENTS WHOSE PARENTS HAVE BACHELOR'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN MATHS WHILE, STUDENTS WHOSE PARENTS HAVE MASTER'S DEGREE ARE NOT PERFORMING WELL
#
# IN GROUP B, STUDENTS WHOSE PARENTS HAVE BACHELOR'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN MATHS WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP C, STUDENTS WHOSE PARENTS HAVE BACHELOR'S DEGREE, MASTER'S DEGREE OR ASSOCIATE'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN MATHS WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP D, STUDENTS WHOSE PARENTS HAVE MASTER'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN MATHS WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP E, STUDENTS WHOSE PARENTS HAVE BACHELOR'S DEGREE, MASTER'S DEGREE OR ASSOCIATE'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN MATHS WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL

# %%
sns.barplot(x='race',y='reading score',data=df,hue='parental_level_of_education')

# %% [markdown]
# IN GROUP A, STUDENTS WHOSE PARENTS HAVE BACHELOR'S DEGREE OR ASSOCIATE'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN READING WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP B, STUDENTS WHOSE PARENTS HAVE MASTER'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN READING WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP C, STUDENTS WHOSE PARENTS HAVE BACHELOR'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN READING WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP D, STUDENTS WHOSE PARENTS HAVE MASTER'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN READING WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP E, STUDENTS WHOSE PARENTS HAVE MASTER'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN READING WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL

# %%
sns.barplot(x='race',y='writing score',data=df,hue='parental_level_of_education')

# %% [markdown]
# IN GROUP A, STUDENTS WHOSE PARENTS HAVE BACHELOR'S DEGREE OR MASTER'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN WRITING WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP B, STUDENTS WHOSE PARENTS HAVE MASTER'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN WRITING WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP C, STUDENTS WHOSE PARENTS HAVE BACHELOR'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN WRITING WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP D, STUDENTS WHOSE PARENTS HAVE MASTER'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN WRITING WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP E, STUDENTS WHOSE PARENTS HAVE MASTER'S DEGREE ARE PERFORMING BETTER THAN OTHERS IN WRITING WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL

# %%
sns.barplot(x='race',y='Avg score',data=df,hue='parental_level_of_education')

# %% [markdown]
# IN GROUP A, STUDENTS WHOSE PARENTS HAVE BACHELOR'S DEGREE ARE PERFORMING BETTER THAN OTHERS WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP B, STUDENTS WHOSE PARENTS HAVE MASTER'S DEGREE ARE PERFORMING BETTER THAN OTHERS WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP C, STUDENTS WHOSE PARENTS HAVE BACHELOR'S DEGREE ARE PERFORMING BETTER THAN OTHERS WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP D, STUDENTS WHOSE PARENTS HAVE MASTER'S DEGREE ARE PERFORMING BETTER THAN OTHERS WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL
#
# IN GROUP E, STUDENTS WHOSE PARENTS HAVE MASTER'S DEGREE ARE PERFORMING BETTER THAN OTHERS WHILE, STUDENTS WHOSE PARENTS HAVE GONE TILL HIGH SCHOOL ARE NOT PERFORMING WELL

# %% [markdown]
# # INFERENCE:-

# %% [markdown]
# PARENTAL EDUCATIONAL LEVEL HAS A HIGH IMPACT ON STUDENT'S PERFORMANCE.
#
# STUDENTS WHOSE PARENTS HAVE BACHELOR'S DEGREE ARE PERFORMING BETTER IN MATHS COMPARED TO OTHERS, WHILE STUDENTS WHOSE PARENTS HAVE MASTER'S DEGREE ARE PERFORMING BETTER IN READING AND WRITING

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,4,1)
sns.scatterplot(x="gender",y='math score',data=df)
plt.subplot(1,4,2)
sns.scatterplot(x="gender",y='reading score',data=df)
plt.subplot(1,4,3)
sns.scatterplot(x="gender",y='writing score',data=df)
plt.subplot(1,4,4)
sns.scatterplot(x="gender",y='Avg score',data=df)

# %% [markdown]
# THERE ARE SOME FEMALE STUDENTS WHO ARE PERFORMING POORLY, BOTH GENDERS ARE ALMOST PERFORMING EQUALLY WITH SOME EXPECTIONS

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,4,1)
sns.scatterplot(x="race",y='math score',data=df)
plt.subplot(1,4,2)
sns.scatterplot(x="race",y='reading score',data=df)
plt.subplot(1,4,3)
sns.scatterplot(x="race",y='writing score',data=df)
plt.subplot(1,4,4)
sns.scatterplot(x="race",y='Avg score',data=df)

# %% [markdown]
# ALMOST EVERY GROUP A AND GROUP D STUDENT IS PERFORMING GOOD
#
# MOST OF THE STUDENTS WHO ARE SCORING LESS ARE FROM MOSTLY GROUP B AND GROUP C

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,4,1)
sns.scatterplot(x="test_preparation_course",y='math score',data=df)
plt.subplot(1,4,2)
sns.scatterplot(x="test_preparation_course",y='reading score',data=df)
plt.subplot(1,4,3)
sns.scatterplot(x="test_preparation_course",y='writing score',data=df)
plt.subplot(1,4,4)
sns.scatterplot(x="test_preparation_course",y='Avg score',data=df)

# %% [markdown]
# NONE OF THE STUDENTS WHO HAVE TAKEN THE COURSE HAVE SCORED LESS
#
# SOME STUDENTS WHO HAVE NOT TAKEN THE COURSE ARE ALSO PERFORMING BETTER

# %%
fig = plt.figure(figsize=(30,15))
sp1 = plt.subplot2grid((2,2),(0,0)) 
sp2 = plt.subplot2grid((2,2),(0,1)) 
sp3 = plt.subplot2grid((2,2),(1,0)) 
sp4 = plt.subplot2grid((2,2),(1,1)) 
sp1.scatter(y="parental_level_of_education",x='math score',data=df)
sp2.scatter(y="parental_level_of_education",x='reading score',data=df)
sp3.scatter(y="parental_level_of_education",x='writing score',data=df)
sp4.scatter(y="parental_level_of_education",x='Avg score',data=df)

# %% [markdown]
# STUDENTS WHOSE PARENTS WHO HAVE GONE TILL HIGH SCHOOL OR COLLEGE HAVE PERFORMED POORLY, BUT VERY FEW OF THEM HAVE PERFORMED EXCEPTIONALLY GOOD
#
# SO PARENT'S EDUCATIONAL LEVEL IS A MAJOR FACTOR BUT IT IS NOT THE ONLY FACTOR

# %%
sns.lmplot(x="math score",y="Avg score",data=df,height=4)

# %%
sns.lmplot(x="reading score", y="Avg score", data=df,height=4)

# %%
sns.lmplot(x="writing score", y="Avg score", data=df,height=4)

# %% [markdown]
# IF A STUDENT IS PERFORMING WELL IN ONE TEST THEN HE IS PERFORMINF EQUALLY WELL IN ALL THE TEST AS THE REGRESSION IS LINEARLY INCRESING

# %%
sns.pairplot(df)

# %%
df.describe()
# Out:
#        math score  reading score  writing score    Avg score
# count  1000.00000    1000.000000    1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000    67.770667
# std      15.16308      14.600192      15.195657    14.257326
# min       0.00000      17.000000      10.000000     9.000000
# 25%      57.00000      59.000000      57.750000    58.333333
# 50%      66.00000      70.000000      69.000000    68.333333
# 75%      77.00000      79.000000      79.000000    77.666667
# max     100.00000     100.000000     100.000000   100.000000

# %%
df.corr()
# Out:
#                math score  reading score  writing score  Avg score
# math score       1.000000       0.817580       0.802642   0.918746
# reading score    0.817580       1.000000       0.954598   0.970331
# writing score    0.802642       0.954598       1.000000   0.965667
# Avg score        0.918746       0.970331       0.965667   1.000000

# %%
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# STUDENTS WHO PERFORM WELL IN READING TEST, GIVE THEIR BEST PERFORMANCE IN ALL THE TESTS, FOLLOWED BY STUDENTES WHO PERFORM WELL IN WRITING TEST THEN MATHS TEST
